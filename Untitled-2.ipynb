# %%
import pandas as pd
import pyarrow as arrow
df_ir = pd.read_parquet("IR_data_chunk001_of_009.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 import pyarrow as arrow
# ----> 3 df_ir = pd.read_parquet("IR_data_chunk001_of_009.parquet")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\parquet.py:668, in read_parquet(path, engine, columns, storage_options, dtype_backend, filesystem, filters, to_pandas_kwargs, **kwargs)
#     508 @set_module("pandas")
#     509 def read_parquet(
#     510     path: FilePath | ReadBuffer[bytes],
#    (...)
#     518     **kwargs,
#     519 ) -> DataFrame:
#     520     """
#     521     Load a parquet object from the file path, returning a DataFrame.
#     522
#    (...)
#     665     1    4    9
#     666     """
# --> 668     impl = get_engine(engine)
#     669     check_dtype_backend(dtype_backend)
#     671     return impl.read(
#     672         path,
# ...
